# %%
import pandas as pd
import numpy as np

# ── Your actual results from the simulation ──────────────
results = {
    # From Day 3 analysis
    'total_restaurants':        500,
    'total_orders':             50000,
    'unreliable_restaurants':   58,       # %
    'high_error_orders':        27,       # % with >5 min label error
    'avg_label_inflation':      2.9,      # minutes
    'avg_rider_wait_data':      23.5,     # minutes (from your dataset)
    'peak_rider_wait':          28.3,     # minutes
    'offpeak_rider_wait':       20.2,     # minutes
    'zomato_visibility':        41,       # % of kitchen load Zomato sees
    'hidden_load':              59,       # % hidden

    # From Day 4 simulation
    'baseline_avg_wait':        7.7,      # minutes
    'improved_avg_wait':        3.4,      # minutes
    'wait_reduction_pct':       55,       # %
    'baseline_p50_error':       7.0,      # minutes
    'improved_p50_error':       3.1,      # minutes
    'baseline_p90_error':       17.9,     # minutes
    'improved_p90_error':       8.2,      # minutes
    'baseline_pct_over10':      32.0,     # %
    'improved_pct_over10':      5.6,      # %
    'severe_case_reduction':    83,       # %
    'annual_saving_cr':         620,      # Rs Crore
}

print("=" * 50)
print("   YOUR MASTER NUMBERS — USE THESE IN PDF")
print("=" * 50)
for key, val in results.items():
    print(f"  {key:<35} {val}")
# Out:
# ...
#    YOUR MASTER NUMBERS — USE THESE IN PDF
# ...
#   total_restaurants                   500
#   total_orders                        50000
#   unreliable_restaurants              58
#   high_error_orders                   27
#   avg_label_inflation                 2.9
#   avg_rider_wait_data                 23.5
#   peak_rider_wait                     28.3
#   offpeak_rider_wait                  20.2
#   zomato_visibility                   41
#   hidden_load                         59
#   baseline_avg_wait                   7.7
#   improved_avg_wait                   3.4
#   wait_reduction_pct                  55
#   baseline_p50_error                  7.0
#   improved_p50_error                  3.1
#   baseline_p90_error                  17.9
#   improved_p90_error                  8.2
#   baseline_pct_over10                 32.0
#   improved_pct_over10                 5.6
#   severe_case_reduction               83
#   annual_saving_cr                    620
